# %% [markdown]
# # Scraping Tweets with the Twitter API

# %% [markdown]
# Tweepy is a library that interfaces with the Twitter API:

# %%
# !pip install tweepy
import tweepy
# weeeply is a python library for accessing twitter data via twitter API. 
# # below I am sharing my demo credenmtials, they will work for testing it,
# but for your project you'll need to create  your own credentials.
# - create a twitter app with your twitter avound (one per group will do) https://developer.twitter.com/en/apps
# - follow the tutorial on tweepy to set it up https://tweepy.readthedocs.io/en/latest/auth_tutorial.html
# Out:
# /bin/sh: /usr/local/bin/pip: /usr/local/opt/python/bin/python3.7: bad interpreter: No such file or directory

# %%
# Specify the account credentials in the following variables:
consumer_key = '6LH2LIMPGNWMxNE2a6LfILp7i'
consumer_secret = '0eWTMNdazgVNCgt1lRCQapeN8O54GeonyGHREyebYQs7dL3upn'
access_token = '78610351-PaQIZu59zNjgIX7OeaKlU1Jr9LMqCTxVmGa7vxLZM'
access_token_secret = 'J32gDj3Vdi3bjB0IbisO0IoCKWadDogVeGgZSyv510jZ4'


# Authenticate
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# Find all English tweets related to #iPhone11 since January 10 2020
for tweet in tweepy.Cursor(api.search, q={"#iPhone11"}, count=5,
                           lang="en", since="2020-01-10").items():
    print("\n-----\n"+str(tweet.created_at), tweet.text+ "\n-----\n")
# Out:
# -----
# 2021-01-09 18:43:35 A #winter #wonderland #walk today on the #derwentwalk - such a beautiful place to live and feel blessed each time w… https://t.co/iLHCzIq2GB
# -----
#
#
# -----
# 2021-01-09 18:43:00 The #iPhone11 was the smartphone with the most new device activations in December 2020, with the #iPhone12ProMax an… https://t.co/NE6eu4JDwG
# -----
#
#
# -----
# 2021-01-09 18:37:28 @Apple the #iphone11 that I got my daughter for xmas has just gone black (when trying to open snapchat) and wont al… https://t.co/brTEQ8XE43
# -----
#
#
# -----
# 2021-01-09 18:32:19 RT @iTech911: Among the top 10 #smartphone models activated on #ChristmasDay 2020, nine were #Apple's #iPhone, with the #iPhone11 holding t…
# -----
#
#
# -----
# 2021-01-09 17:43:36 A #winter #robin on the #DerwentWalk earlier today, perched on a snowy bench.
# .
#
# .
# 📷 #iphone11
# #shotoniphone… https://t.co/0YrKwWmhH7
# -----
#
#
# -----
# 2021-01-09 17:24:44 RT @MacObserver: The blended materials costs for the 128 GB #iPhone12 come in at nearly $415, a 21 percent increase on the #iPhone11, accor…
# -----
#
#
# -----
# 2021-01-09 17:11:25 RT @MacObserver: The blended materials costs for the 128 GB #iPhone12 come in at nearly $415, a 21 percent increase on the #iPhone11, accor…
# -----
#
#
# -----
# 2021-01-09 16:53:54 Marlow at Sunset, 2021. A wonderful view of #marlow this evening from my the Flackwell Allotments.
# 📷 #iphone… https://t.co/dNRvkLMM8W
# -----
#
#
# -----
# 2021-01-09 16:26:02 RT @MaksciaMind: Leggings ● Bags ● iPhone Cases -》》》
# Leopard Collection ● LINK  -》》》 https://t.co/SZF1Y4DcF5
#
# #coverforiphone #iPhone12mini…
# -----
#
#
# -----
# 2021-01-09 16:10:11 RT @AR72014: #wallpaper #iPhone12
#
# #iPhone12Pro - #iPhone12ProMax stock (Light&amp;Dark) #wallpapers for
#
# - #iPhone11ProMax
# - #iPhone11Pro
# - #…
# -----
#
#
# -----
# 2021-01-09 15:45:38 RT @9techeleven: 9/10 of the #Top10 Smartphones activated on Christmas Day in the Us were iPhones 🤯 according to @FlurryMobile
#
# -----
# 2021-01-09 05:40:41 ❄️night #mobilephotography #iphone11 https://t.co/jdCgXDD9dx
# -----
#
#
# -----
# 2021-01-09 03:47:13 #iphone11 🐐 mode #iPhones
#
# Fuck your 🛋
# -----
#
#
# -----
# 2021-01-09 03:46:44 @BrandiMelvin2 🤣🙌 #iphone11 is enough 💯
# -----
#
#
# -----
# 2021-01-09 03:20:00 The blended materials costs for the 128 GB #iPhone12 come in at nearly $415, a 21 percent increase on the #iPhone11… https://t.co/3kQtdHdLVC
# -----
#
#
# -----
# 2021-01-09 03:05:06 Yay I finally upgraded my phone. #iphone11 #virginmobile #upgrade https://t.co/q15p1YAMVS
# -----
#
#
# -----
# 2021-01-09 02:17:18 Online #MysteryBox Sale! Unbox iPhone 11 Pro Gold or Midnight Green at no cost! #iPhone11 https://t.co/KcaOIGQAaF
# -----
#
#
# -----
# 2021-01-09 02:14:04 RT @AR72014: #wallpaper #AirPodsMax
#
# AirPods Max Colors (DUO) #wallpapers
#
# for
#
# - #iPhone12ProMax
# - #iPhone12Pro
# - #iPhone12
# - #iPhone12…
# -----
#
#
# -----
# 2021-01-09 00:29:05 RT @ImagineApplePR: 🎉NEW YEAR OFFERS @ IMAGINE🎊
#
# It’s time to surround yourself with an amazing gift. Get exciting offers on iPhone at Imag…
# -----
#
#
# -----
# 2021-01-09 00:21:23 The best #camera is the one you have with you. This incredible #sunrise shot was taken on an #iPhone11ProMax! 🤳 Wha… https://t.co/3CAyp9Qhrm
# -----
#
#
# -----
# 2021-01-08 23:45:05 RT @FavoriteTechX: iPhone Ringtone Evolution 🎵
#
# https://t.co/cPD3RYQb36
#
# via @YouTube #apple #iphone #iphone12 #iphone12pro #gold #iphone…
# -----
#
#
# -----
# 2021-01-08 23:45:05 RT @ruffsnap: 700+ custom #ios14icons for EVERY app you have! $5 off w/ code "ilovetwitter"! https://t.co/SPym50nNTB #Icons #iPhone12TH #iP…
# -----
#
#
# -----
# 2021-01-08 23:43:34 RT @humanplaylistr: I’m working on some new #playlists for the new year. In these fraught times I’m looking for a #peaceful state of mind.…
# -----
#
#
# -----
# 2021-01-08 23:33:37 iPhone Ringtone Evolution 🎵
#
# https://t.co/cPD3RYQb36
#
# via @YouTube #apple #iphone #iphone12 #iphone12pro #gold… https://t.co/s1D4QRZjbg
# -----
#
#
# -----
# 2021-01-08 23:26:52 RT @ruffsnap: 700+ custom #ios14icons for EVERY app you have! $5 off w/ code "ilovetwitter"! https://t.co/SPym50nNTB #Icons #iPhone12TH #iP…
# -----
#
#
# -----
# 2021-01-08 23:05:46 Moosey heard somethin.
#
#  #mutt #pit #boxer #pitboxer #muttstagram #moosebandicoot #mooseybandito #bostonterrier… https://t.co/oEemfkMcuS
# -----
#
#
# -----
# 2021-01-08 22:48:31 I’m working on some new #playlists for the new year. In these fraught times I’m looking for a #peaceful state of mi… https://t.co/xLVau0oIcH
# -----
#
#
# -----
# 2021-01-08 21:26:38 RT @chisomegu1: school’s should really start teaching sex education tbvh #BBNaija #davido #LayconNeedsYou #iphone11
# -----
#
#
# -----
# 2021-01-08 20:57:48 Check out Mathew N. Perry's video! #TikTok #Apple #iPhone11  https://t.co/68AaNssrbh
# -----
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-70f772dcd18f> in <module>
#      14 # Find all English tweets related to #iPhone11 since January 10 2020
#      15 for tweet in tweepy.Cursor(api.search, q={"#iPhone11"}, count=5,
# ---> 16                            lang="en", since="2020-01-10").items():
#      17     print("\n-----\n"+str(tweet.created_at), tweet.text+ "\n-----\n")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     345             or IS_SECURETRANSPORT):
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#     349         warnings.warn(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
# --> 458                 if not util.wait_for_read(sock, sock.gettimeout()):
#     459                     raise timeout('select timed out')
#     460                 continue
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# You can also 'listen in' on Twitter as tweets are posted in real-time: but this is much more buggy and complex. But you might see a few tweets before the whole thing crashes:

# %%
import json

# Specify the account credentials in the following variables:
consumer_key = '6LH2LIMPGNWMxNE2a6LfILp7i'
consumer_secret = '0eWTMNdazgVNCgt1lRCQapeN8O54GeonyGHREyebYQs7dL3upn'
access_token = '78610351-PaQIZu59zNjgIX7OeaKlU1Jr9LMqCTxVmGa7vxLZM'
access_token_secret = 'J32gDj3Vdi3bjB0IbisO0IoCKWadDogVeGgZSyv510jZ4'


# This listener will print out all Tweets it receives
class PrintListener(tweepy.StreamListener):
    def on_data(self, data):
        
        # Decode the JSON data
        tweet = json.loads(data)

        # Print out the Tweet
        print(f"{ tweet['user']['screen_name']}  {tweet['text'].encode('ascii', 'ignore')} \n\n")

    def on_error(self, status):
        print("Error", status)


print("about to start")
if __name__ == '__main__':
    listener = PrintListener()

    keyword = 'Python'

    # Show system message
    print('I will now print Tweets containing "' + keyword + '" As they are posted live ==>')

    # Authenticate
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    # Connect the stream to our listener
    stream = tweepy.Stream(auth, listener)
    stream.filter(track=[keyword])
              
# to stop the program (please don't keep it running) use the Stop button on the top of your screen (next to RUN)
# Out:
# about to start
# I will now print Tweets containing "Python" As they are posted live ==>
# BAMBVDESIGN  b'&amp; C:/Users/Exa/AppData/Local/Programs/Python/Python39/python.exe "c:/Users/Exa/Desktop/Bambv/Py files/Generative Ar https://t.co/jXRfN6j9FS'
#
#
# AdvanceML  b'RT @InterSystemsDev:  How to build #MultiModel solutions using #InterSystemsIRIS? Join the kick-off #webinar &amp; take part in our current #p'
#
#
# devvibesbot  b'RT @Kada_soulayman: Time : 2021-01-09T18:50:45.5211159Z\n\n#Coding Test now.\n#Someone #dark #Python #C++ #Telegram #facebook #twitter #instag'
#
#
# Mantame1  b'RT @HighbrowTutor: Hello scholar.\nKindly reach out for help:\n#FinalExam\n#Assignment \n#quiz \n#Math \n#JavaScript \n#Programming \n#AllCourses'
#
#
# LlnuxBot  b'RT @CourseGift: [BEST] #Udemy Time Series Analysis in Python 2021 (+7 Hours) Course \n\n https://t.co/GLkA5Y35Pa \n\n#BigData #Analytics #Dat'
#
#
# smithdetails  b'@IiminaIity_ python'
#
#
# morolswediu  b'RT @phoenixfire2912: #100DaysOfCode Day 015: Thank you @EstefaniaCassN @freeCodeCamp for this helpful article.\n\nPython While Loop Tutorial'
#
#
# morolswediu  b'RT @CourseGift: [BEST] #Udemy Time Series Analysis in Python 2021 (+7 Hours) Course \n\n https://t.co/GLkA5Y35Pa \n\n#BigData #Analytics #Dat'
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0172cb4a203c> in <module>
#      37     # Connect the stream to our listener
#      38     stream = tweepy.Stream(auth, listener)
# ---> 39     stream.filter(track=[keyword])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     307                 raise
#     308         except OpenSSL.SSL.WantReadError:
# --> 309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     310                 raise timeout('The read operation timed out')
#     311             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
